# %%
a=[1,12,123,1234,123456,]
b=[10,"hello",True,10.234]
print(a)
print(b)
# Out:
# [1, 12, 123, 1234, 123456]
# [10, 'hello', True, 10.234]

# %%
a=[10,20,30,40,50,60]
a.append(27)
print(a)
# Out:
# [10, 20, 30, 40, 50, 60, 27]

# %%
a=[10,20,30,40,50,60]
a.count(40)
# Out:
# 1

# %%
a.index(30)
# Out:
# 2

# %%
a.insert(4,168)
print(a)
# Out:
# [10, 20, 30, 40, 168, 168, 50, 60, 27]

# %%
a.pop(3)
# Out:
# 40

# %%
a.remove(10)
print(a)
# Out:
# [30, 168, 168, 60, 27]

# %%
a.reverse()
print(a)
# Out:
# [27, 60, 168, 168, 30]

# %%
c=a.copy()
print(c)
# Out:
# [30, 168, 168, 60, 27]

# %%
print(a)
# Out:
# [27, 30, 60, 168, 168]

# %%
a.append(21)
a.append(34)
a.append(1)
a.append(967)
a.append(51)

# %%
print(a)
# Out:
# [27, 30, 60, 168, 168, 21, 34, 1, 967, 51]

# %%
a.sort()
print(a)
# Out:
# [1, 1, 1, 1, 1, 21, 21, 21, 21, 21, 21, 27, 30, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 51, 51, 51, 51, 51, 60, 168, 168, 168, 967, 967, 967, 967, 967]

# %%
a.sort()

# %%
a
# Out:
# [1,
#  1,
#  1,
#  1,
#  1,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  27,
#  30,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  51,
#  51,
#  51,
#  51,
#  51,
#  60,
#  168,
#  168,
#  168,
#  967,
#  967,
#  967,
#  967,
#  967]

# %%
x = sorted(set(a))

# %%
x
# Out:
# [1, 21, 27, 30, 34, 51, 60, 168, 967]

# %%
print(x)
# Out:
# [1, 21, 27, 30, 34, 51, 60, 168, 967]

# %%
x[3:]
# Out:
# [30, 34, 51, 60, 168, 967]

# %%
x[:]
# Out:
# [1, 21, 27, 30, 34, 51, 60, 168, 967]

# %%
x[1:3]
# Out:
# [21, 27]

# %%
x[-1]
# Out:
# 967

# %%
x.extend([45,55,65])
print(x)
# Out:
# [1, 21, 27, 30, 34, 51, 60, 168, 967, 45, 55, 65, 45, 55, 65]

# %%
x[1:3:7]
# Out:
# [21]

# %%
g=(10,20,30,30,40,50)
print(g)
# Out:
# (10, 20, 30, 30, 40, 50)

# %%
g.append(26)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 g.append(26)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
g.count(30)
# Out:
# 2

# %%
g.index(40)
# Out:
# 4

# %%
len(g)
# Out:
# 6

# %%
min(g)
# Out:
# 10

# %%
max(g)
# Out:
# 50

# %%
sum(g)
# Out:
# 180

# %%
sorted(g)
# Out:
# [10, 20, 30, 30, 40, 50]

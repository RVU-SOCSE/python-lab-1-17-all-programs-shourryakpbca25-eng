# %%
import pandas as pd
data={'Name':['Rama','Krishna','Sita','Lakshmana'],
     'Age':[20,38,47,25],
     'Salary':[50000,27000,35000,80000]}
df=pd.DataFrame(data)
print("Dataframe from scratch:")
print(df)
#adding new column
df['Bonus']=df['Salary']*0.10
print("\n DataFrame after bonus column is :")
print(df)
# Out:
# Dataframe from scratch:
#         Name  Age  Salary
# 0       Rama   20   50000
# 1    Krishna   38   27000
# 2       Sita   47   35000
# 3  Lakshmana   25   80000
#
#  DataFrame after bonus column is :
#         Name  Age  Salary   Bonus
# 0       Rama   20   50000  5000.0
# 1    Krishna   38   27000  2700.0
# 2       Sita   47   35000  3500.0
# 3  Lakshmana   25   80000  8000.0

# %%
import pandas as pd 
df=pd.read_csv("C:\\Users\\RVUW251\\shourrya_0100\\dataset.csv")
print("First six rows from the dataframe:")
print(df.head(6))
print("\n column and data types:")
print(df.info())
# Out:
# First six rows from the dataframe:
#    Year  McDonalds_Revenue_$Billion  Growth_rate_percent   Q1   Q2   Q3   Q4
# 0  1999                        13.3                  NaN  NaN  NaN  NaN  NaN
# 1  2000                        14.2                  7.0  NaN  NaN  NaN  NaN
# 2  2001                        14.9                  4.0  NaN  NaN  NaN  NaN
# 3  2002                        15.4                  4.0  NaN  NaN  NaN  3.0
# 4  2003                        17.1                 11.0  3.8  4.3  4.5  4.6
# 5  2004                        18.6                  8.0  4.4  4.7  4.9  4.5
#
#  column and data types:
# <class 'pandas.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year                        24 non-null     int64
#  1   McDonalds_Revenue_$Billion  24 non-null     float64
# ...

# %%
import pandas as pd 
df=pd.read_csv("C:\\Users\\RVUW251\\shourrya_0100\\dataset.csv")
print(df)

print("\n missing values in the dataframe is :")
print(df.isnull().sum())

df.Q1=df['Q1'].fillna(df['Q1'].mean())

print(df.Q1)
# Out:
#     Year  McDonalds_Revenue_$Billion  Growth_rate_percent   Q1   Q2   Q3   Q4
# 0   1999                        13.3                  NaN  NaN  NaN  NaN  NaN
# 1   2000                        14.2                  7.0  NaN  NaN  NaN  NaN
# 2   2001                        14.9                  4.0  NaN  NaN  NaN  NaN
# 3   2002                        15.4                  4.0  NaN  NaN  NaN  3.0
# 4   2003                        17.1                 11.0  3.8  4.3  4.5  4.6
# 5   2004                        18.6                  8.0  4.4  4.7  4.9  4.5
# 6   2005                        19.1                  3.0  4.8  5.1  5.3  3.9
# 7   2006                        20.9                  9.0  4.9  5.4  5.5  5.1
# 8   2007                        22.8                  9.0  5.3  5.8  5.9  5.8
# 9   2008                        23.5                  3.0  5.6  6.1  6.3  5.6
# 10  2009                        22.7                 -3.0  5.1  5.6  6.0  6.0
# ...

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\RVUW251\\shourrya_0100\\dataset.csv")
print(df)

print(df.Growth_rate_percent.mean())
print(df.Growth_rate_percent.median())
print(df.Growth_rate_percent.mode()[0])
print(df.Growth_rate_percent.min())
print(df.Growth_rate_percent.max())
print(df.Growth_rate_percent.var())
# Out:
#     Year  McDonalds_Revenue_$Billion  Growth_rate_percent   Q1   Q2   Q3   Q4
# 0   1999                        13.3                  NaN  NaN  NaN  NaN  NaN
# 1   2000                        14.2                  7.0  NaN  NaN  NaN  NaN
# 2   2001                        14.9                  4.0  NaN  NaN  NaN  NaN
# 3   2002                        15.4                  4.0  NaN  NaN  NaN  3.0
# 4   2003                        17.1                 11.0  3.8  4.3  4.5  4.6
# 5   2004                        18.6                  8.0  4.4  4.7  4.9  4.5
# 6   2005                        19.1                  3.0  4.8  5.1  5.3  3.9
# 7   2006                        20.9                  9.0  4.9  5.4  5.5  5.1
# 8   2007                        22.8                  9.0  5.3  5.8  5.9  5.8
# 9   2008                        23.5                  3.0  5.6  6.1  6.3  5.6
# 10  2009                        22.7                 -3.0  5.1  5.6  6.0  6.0
# ...

# %%
z={1,4,2,7,3,8,3}
y={2,5,8,3,6,9}

z.add(9)
print(z)
# Out:
# {1, 2, 3, 4, 7, 8, 9}

# %%
h=z.copy()
print(h)
# Out:
# {1, 2, 3, 4, 7, 8, 9}

# %%
z.union(y)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
z.intersection(y)
# Out:
# {2, 3, 8, 9}

# %%
z.difference(y)
# Out:
# {1, 4, 7}

# %%
y.difference(z)
# Out:
# {5, 6}

# %%
z.symmetric_difference(y)
# Out:
# {1, 4, 5, 6, 7}

# %%
z.discard(4)
print(z)
# Out:
# {1, 2, 3, 7, 8, 9}

# %%
z.update([10,20])
print(z)
# Out:
# {1, 2, 3, 20, 7, 8, 9, 10}

# %%
z.isdisjoint(y)
# Out:
# False

# %%
z
# Out:
# {1, 2, 3, 7, 8, 9, 10, 20}

# %%
y
# Out:
# {2, 3, 5, 6, 8, 9}

# %%
z.issuperset(y)
# Out:
# False

# %%
z.issubset(y)
# Out:
# False

# %%
y.issubset(z)
# Out:
# False

# %%
y.issuperset(z)
# Out:
# False

# %%
z={1,4,2,7,3,8,3}
y={2,5,8,3,6,9}
print(y)
print(z)
# Out:
# {2, 3, 5, 6, 8, 9}
# {1, 2, 3, 4, 7, 8}

# %%
popped_element=y.pop()
print(popped_element)
print(y)
# Out:
# 2
# {3, 5, 6, 8, 9}

# %%
y.update([7,17,28,11])
print(y)
# Out:
# {3, 5, 6, 7, 8, 9, 11, 17, 28}

# %%
len(y)
# Out:
# 9

# %%
iter(y)

# %%
repr(y)
# Out:
# '{3, 5, 6, 7, 8, 9, 11, 17, 28}'

# %%
y.difference(z)
# Out:
# {5, 6, 9, 11, 17, 28}

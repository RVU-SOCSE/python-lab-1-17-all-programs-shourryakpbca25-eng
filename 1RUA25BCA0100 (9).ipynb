# %%
import pandas as pd
# Load the CSV file
df=pd.read_csv("C:\\Users\\RVUW251\\shourrya_0100\\lab5_dataset.csv")
print(df)

# Displaying the basic central tendencies and dispersion metrics and results
print(df.YearsExperience.mean())
print(df.YearsExperience.median())
print(df.YearsExperience.mode()[0]) # incase multiple mode add [0]
print(df.YearsExperience.min())
print(df.YearsExperience.max())
print(df.YearsExperience.var())
print(df.YearsExperience.std())
# Out:
#    YearsExperience
# 0              1.1
# 1              1.3
# 2              1.5
# 3              2.0
# 4              2.2
# 5              2.9
# 6              3.0
# 7              3.2
# 8              3.2
# 2.266666666666667
# 2.2
# 3.2
# 1.1
# 3.2
# 0.7050000000000001
# 0.8396427811873333

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\RVUW251\\shourrya_0100\\lab5_dataset.csv")
print(df)
# Out:
#    YearsExperience
# 0              1.1
# 1              1.3
# 2              1.5
# 3              2.0
# 4              2.2
# 5              2.9
# 6              3.0
# 7              3.2
# 8              3.2

# %%
df.YearsExperience.mean()
# Out:
# np.float64(2.266666666666667)

# %%
mean_value = df['YearsExperience'].mean()
print(mean_value)
# Out:
# 2.266666666666667

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\RVUW251\\shourrya_0100\\lab5_dataset.csv")
print(df.quantile([0.25,0.5,0.75]))
print(df.describe()) #summary
print(df) #to print the database

#other method for description
description=df.describe()
print(description)
# Out:
#       YearsExperience
# 0.25              1.5
# 0.50              2.2
# 0.75              3.0
#        YearsExperience
# count         9.000000
# mean          2.266667
# std           0.839643
# min           1.100000
# 25%           1.500000
# 50%           2.200000
# 75%           3.000000
# max           3.200000
#    YearsExperience
# 0              1.1
# 1              1.3
# 2              1.5
# 3              2.0
# 4              2.2
# 5              2.9
# 6              3.0
# 7              3.2
# 8              3.2
#        YearsExperience
# count         9.000000
# mean          2.266667
# std           0.839643
# min           1.100000
# 25%           1.500000
# 50%           2.200000
# 75%           3.000000
# max           3.200000

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\RVUW251\\shourrya_0100\\lab5_dataset.csv")
skewness = df['YearsExperience'].skew() 
kurtosis = df['YearsExperience'].kurt() 
print(df.skew())
print(df.kurt())
# Out:
# YearsExperience   -0.18643
# dtype: float64
# YearsExperience   -1.85304
# dtype: float64

# %%
quantiles = df['YearsExperience'].quantile([0.25, 0.5, 0.75]) 
print(quantiles)
# Out:
# 0.25    1.5
# 0.50    2.2
# 0.75    3.0
# Name: YearsExperience, dtype: float64

# %%
skewness = df['YearsExperience'].skew() 
print("the skewness is: ", skewness )
kurtosis = df['YearsExperience'].kurt()
print("the kurtosis is: ", kurtosis)
# Out:
# the skewness is:  -0.18643041769017651
# the kurtosis is:  -1.8530398729583881

# %%
value_counts = df['YearsExperience'].value_counts() 
print(value_counts)
# Out:
# YearsExperience
# 3.2    2
# 1.1    1
# 1.3    1
# 1.5    1
# 2.0    1
# 2.2    1
# 2.9    1
# 3.0    1
# Name: count, dtype: int64

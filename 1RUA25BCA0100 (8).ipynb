# %%
import os
os.mkdir("BCAB_PY")

# %%
os.listdir()
os.getcwd()
# Out:
# 'C:\\Users\\RVUW251\\shourrya_0100'

# %%
os.rename("output.csv","newoutput.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 os.rename("output.csv","newoutput.csv")
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'output.csv' -> 'newoutput.csv'

# %%
import shutil
shutil.copy("students.csv","BCAB_PY/newoutputcpy.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 import shutil
# ----> 2 shutil.copy("students.csv","BCAB_PY/newoutputcpy.csv")
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\shutil.py:489, in copy(src, dst, follow_symlinks)
#     487 if os.path.isdir(dst):
#     488     dst = os.path.join(dst, os.path.basename(src))
# --> 489 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     490 copymode(src, dst, follow_symlinks=follow_symlinks)
#     491 return dst
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\shutil.py:313, in copyfile(src, dst, follow_symlinks)
#     311     os.symlink(os.readlink(src), dst)
#     312 else:
# --> 313     with open(src, 'rb') as fsrc:
#     314         try:
#     315             with open(dst, 'wb') as fdst:
#     316                 # macOS
#
# ...

# %%
import shutil
shutil.copytree("Documents","Documents1234")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 import shutil
# ----> 2 shutil.copytree("Documents","Documents1234")
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\shutil.py:652, in copytree(src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     613 """Recursively copy a directory tree and return the destination directory.
#     614
#     615 If exception(s) occur, an Error is raised with a list of reasons.
#    (...)    649 `src` tree.
#     650 """
#     651 sys.audit("shutil.copytree", src, dst)
# --> 652 with os.scandir(src) as itr:
#     653     entries = list(itr)
#     654 return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#     655                  ignore=ignore, copy_function=copy_function,
#     656                  ignore_dangling_symlinks=ignore_dangling_symlinks,
# ...

# %%
import shutil
shutil.move("abc.csv","BCAB_PY/abcmove.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\shutil.py:918, in move(src, dst, copy_function)
#     917 try:
# --> 918     os.rename(src, real_dst)
#     919 except OSError:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'abc.csv' -> 'BCAB_PY/abcmove.csv'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 import shutil
# ----> 2 shutil.move("abc.csv","BCAB_PY/abcmove.csv")
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\shutil.py:938, in move(src, dst, copy_function)
#     936         rmtree(src)
#     937     else:
# --> 938         copy_function(src, real_dst)
#     939         os.unlink(src)
#     940 return real_dst
#
# ...

# %%
a1 = {"hi":"python"}
a2 = {"shourrya":"new_class"}
a1.update(a2)
print(a1.keys())
for i in a1.items():
    print(i)
# Out:
# dict_keys(['hi', 'shourrya'])
# ('hi', 'python')
# ('shourrya', 'new_class')

# %%
a= [1,2,3,4]
print(a[1])
# Out:
# 2

# %%
d1 = {1:"h",2:"e"}
d2 = {2:"l",3:"i"}
d3 = d1 | d2
print(d3)
# Out:
# {1: 'h', 2: 'l', 3: 'i'}

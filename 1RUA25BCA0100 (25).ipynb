# %%
import pandas as pd
data = pd.Series([10,20,30,40])  
print(data)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
data = pd.Series([10,20,30],index=["x","y","z"])
print(data)
# Out:
# x    10
# y    20
# z    30
# dtype: int64

# %%
data = {
    "Name": ["Ram", "Vani"],
    "Age": [20,25 ]
}

df = pd.DataFrame(data)
print(df)
print("\n")
#print(df.Name) #  or df["Name"]   # access based on col

print(df.loc[0]) # or df.loc[0,"col_Name"]  # 0th-row, Particular Col    #acess base on row

#print(df.loc[1])
# Out:
#    Name  Age
# 0   Ram   20
# 1  Vani   25
#
#
# Name    Ram
# Age      20
# Name: 0, dtype: object

# %%
df=pd.read_csv(""C:\Users\RVUW251\Desktop\hi.txt"")
print(df)
# Out:
#   Cell In[14], line 1
#     df=pd.read_csv(""C:\Users\RVUW251\Desktop\hi.txt"")
#                    ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
df.isnull()
# Out:
#     Name    Age
# 0  False  False
# 1  False  False

# %%
df.dropna()  # remove the missing data
# Out:
#    Name  Age
# 0   Ram   20
# 1  Vani   25

# %%
# basic statistics method
print(df["Marks"].mean())
print(df.Marks.sum())
print(df.Marks.min())
print(df.Marks.max())
print(df.Marks.count())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Marks'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 2
# ...
